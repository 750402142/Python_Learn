# %%
import pandas as pd

# 任务1
# 读取所有文件数据
data = pd.read_excel('./中国大学数据/全国高校名单及详细指标.xls')
dt1 = pd.read_csv('./中国大学数据/bcur_2015.csv',encoding='utf-8')
dt1["年份"] = 2015
dt2 = pd.read_csv('./中国大学数据/bcur_2016.csv',encoding='utf-8')
dt2["年份"] = 2016
dt3 = pd.read_csv('./中国大学数据/bcur_2017.csv',encoding='utf-8')
dt3["年份"] = 2017
dt4 = pd.read_csv('./中国大学数据/bcur_2018.csv',encoding='utf-8')
dt4["年份"] = 2018
dt5 = pd.read_csv('./中国大学数据/bcur_2019.csv',encoding='utf-8')
dt5["年份"] = 2019
dt6 = pd.read_csv('./中国大学数据/bcur_2020.csv',encoding='utf-8')
dt6["年份"] = 2020
dt7 = pd.read_csv('./中国大学数据/bcur_2021.csv',encoding='utf-8')
dt7["年份"] = 2021
dt8 = pd.read_csv('./中国大学数据/bcur_2022.csv',encoding='utf-8')
dt8["年份"] = 2022
dt9 = pd.read_excel('./中国大学数据/中国大学综合排名2023.xlsx')
dt9["年份"] = 2023
dt10 = pd.read_csv('./中国大学数据/中国大学综合排名2024.csv',encoding='utf-8')
dt10["年份"] = 2024

# %%
columns = ['年份', '排名', '学校名称', '英文名称', '层次', '类型', '地区', '评分']
dt9_new = dt9[["年份",'排名','学校名称','英文名称','层次','类型','地区','评分']]
dt10_new = dt10[['年份','排名','中文名','英文名','标签','地址','行业','分数']]
dt10_new.columns = dt9_new.columns = columns

# %%
data = data[['院校名称','建校时间','隶属于','硕士点','重点实验室','院校类型','办学类型','办学性质','占地面积']]
data.columns = ['学校名称','建校时间','隶属于','硕士点','重点实验室','院校类型','办学类型','办学性质','占地面积']

# %%
# 合并数据
new_data1=pd.concat([dt1,dt2,dt3,dt4,dt5,dt6,dt7,dt8],ignore_index=True)
new_data11 = new_data1[['年份','ranking','univNameCn','univNameEn','univTags',  'univCategory','province','score']]

# %%
new_data11.columns = columns
new_data = pd.concat([new_data11,dt9_new,dt10_new],ignore_index=True)

# %%
all_school = pd.merge(new_data,data,on = '学校名称',how='left')
all_school
# Out:
#         年份   排名          学校名称  \
# 0     2015    1          清华大学
# 1     2015    2          北京大学
# 2     2015    3          浙江大学
# 3     2015    4        上海交通大学
# 4     2015    5          复旦大学
# ...    ...  ...           ...
# 6363  2024  589  河北科技工程职业技术大学
# 6364  2024  591    河北石油职业技术大学
# 6365  2024  592        新疆政法学院
# 6366  2024  593    广西农业职业技术大学
# 6367  2024  594        山西科技学院
#
#                                                    英文名称           层次  类型  地区  \
# 0                                   Tsinghua University  双一流 985 211  理工  北京
# 1                                     Peking University  双一流 985 211  综合  北京
# 2                                   Zhejiang University  双一流 985 211  综合  浙江
# 3                         Shanghai Jiao Tong University  双一流 985 211  综合  上海
# 4                                      Fudan University  双一流 985 211  综合  上海
# ...                                                 ...          ...  ..  ..
# 6363  North China Electric Power University Science ...          NaN  河北  理工
# 6364        Hebei University of Technology City College          NaN  河北  理工
# 6365   Xinjiang University of Political Science and Law          NaN  新疆  综合
# 6366       Guangxi Vocational University of Agriculture          NaN  广西  综合
# 6367         Shanxi Institute of Science and Technology          NaN  山西  理工
#
#         评分    建校时间       隶属于   硕士点  重点实验室 院校类型    办学类型 办学性质    占地面积
# 0     94.0  1911.0       教育部  65.0   13.0  综合类    普通本科   公办  6632.0
# 1     81.0  1898.0       教育部  50.0   47.0  综合类    普通本科   公办  7000.0
# 2     80.0  1897.0       教育部  62.0   28.0  综合类    普通本科   公办  9335.0
# 3     78.0  1896.0       教育部  57.0   22.0  综合类    普通本科   公办  4500.0
# 4     72.0  1905.0       教育部  43.0   26.0  综合类    普通本科   公办   603.0
# ...    ...     ...       ...   ...    ...  ...     ...  ...     ...
# 6363  60.5  1979.0       河北省   0.0    0.0  理工类  专科（高职）   公办  1300.0
# 6364  55.0  1903.0    河北省教育厅   0.0    0.0  理工类    普通本科   公办  1000.0
# 6365  54.9  2002.0  新疆生产建设兵团   0.0    0.0  理工类    普通本科   公办  2691.0
# 6366  51.4     NaN       NaN   NaN    NaN  NaN     NaN  NaN     NaN
# 6367  49.7     NaN       NaN   NaN    NaN  NaN     NaN  NaN     NaN
#
# [6368 rows x 16 columns]

# %%
new_data.shape[0]
# Out:
# 5075
