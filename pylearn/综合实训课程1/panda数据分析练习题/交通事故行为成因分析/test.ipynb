# %%
from idlelib.iomenu import encoding

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import sys
print('Python version:', sys.version)
print('Pandas version:', pd.__version__)
print('Numpy version:', np.__version__)
print('Matplotlib version:', matplotlib.__version__)
# Out:
# Python version: 3.10.9 (tags/v3.10.9:1dd9be6, Dec  6 2022, 20:01:21) [MSC v.1934 64 bit (AMD64)]
# Pandas version: 2.2.2
# Numpy version: 2.1.1
# Matplotlib version: 3.9.2

# %%
data = pd.read_csv('./data/accid1.csv',encoding='gbk')
data
# Out:
#           accidenttime accidentaddr             driver1fault  \
# 0        2015/2/4 8:23       花溪大道北段               7、未按规定让行的
# 1        2015/2/4 8:40       花溪区孟关乡                    3、倒车的
# 2        2015/2/4 7:20         白金大道                    1、追尾的
# 3        2015/2/4 9:20           金阳               7、未按规定让行的
# 4        2015/2/4 9:00          新华路  9、不符合前8款规定或者双方同时具有上述情形的
# ...                ...          ...                      ...
# 18036  2015/5/10 22:26          贵开路               7、未按规定让行的
# 18037   2015/2/5 17:20         林城西路               7、未按规定让行的
# 18038  2015/4/16 12:30         金珠大道                    1、追尾的
# 18039  2015/2/12 13:01          蟠桃宫               7、未按规定让行的
# 18040   2015/3/16 8:00         大理石路            8、依法应负全责的其他情形
#
#       driver1responsibility driver2responsibility  sex1 platenumber1  \
# 0                     负全部责任                  不负责任     1      贵AVG423
# 1                     负全部责任                  不负责任     1      贵AKC352
# 2                     负全部责任                  不负责任     1      贵A24876
# 3                     负全部责任                  不负责任     1      贵A7287L
# 4                     负同等责任                 负同等责任     1      贵AU1522
# ...                     ...                   ...   ...          ...
# 18036                 负同等责任                 负同等责任     1      贵A7294C
# 18037                 负全部责任                  不负责任     1      贵GT6092
# 18038                 负全部责任                  不负责任     1      贵HCU696
# 18039                 负全部责任                  不负责任     1      贵HV8443
# 18040                 负全部责任                  不负责任     1      贵B34129
#
#       carcolor1  sex2 platenumber2  ... jxmc1        jxmc2          cclzrq1  \
# 0            白色     1      贵A74653  ...    -1         贵大驾校               -1
# 1            白色     1      贵A6156A  ...    -1  贵州省长安驾驶培训学校               -1
# 2             蓝     1      贵AN6491  ...  鑫鑫驾校           -1  2006/11/30 0:00
# 3             黑     0      贵A7088C  ...  消防驾校       520116   2004/6/17 0:00
# 4            白色     1      贵A68C55  ...    自培           自培   2006/1/23 0:00
# ...         ...   ...          ...  ...   ...          ...              ...
# 18036         红     1      贵CHT461  ...    自培           自培   2004/1/13 0:00
# 18037         黑     1      贵AAS408  ...    自培           自培  2002/11/11 0:00
# 18038         银     1      贵A67R99  ...    自培           自培   2002/4/19 0:00
# 18039         蓝     0      贵JDN385  ...    自培           自培   2003/5/22 0:00
# 18040        黑色     1      贵AYY148  ...    自培           自培   2002/4/15 0:00
#
#                cclzrq2 clpp1  clpp2       driver1license       driver2license  \
# 0        2013/6/7 0:00   朗逸牌    新感觉   36455619349666600   366577000000000000
# 1       2013/9/16 0:00   长安牌    起亚牌  354664000000000000   364556000000000000
# 2                   -1   华神牌    银翔牌  366364000000000000   364558000000000000
# 3       2008/5/29 0:00   众泰牌    长安牌  366068000000000000   364557000000000000
# 4       2012/9/14 0:00   大众牌    海马牌  366577000000000000   364548000000000000
# ...                ...   ...    ...                  ...                  ...
# 18036   2014/11/5 0:00   俊风牌  北京现代牌  364557000000000000   366564000000000000
# 18037  2001/12/31 0:00   英伦牌    银钢牌  356168000000000000   366361000000000000
# 18038   2014/2/17 0:00   长安牌  北京现代牌  364548000000000000   364548000000000000
# 18039  2000/12/27 0:00  纳智捷牌  东风标致牌  366246000000000000   366667000000000000
# 18040  2003/10/11 0:00   长城牌    五菱牌  354663000000000000   354663000000000000
#
#        brith1  brith2
# 0      985082  199006
# 1      196904  199402
# 2      196907  198508
# 3      197512  197906
# 4      197209  197701
# ...       ...     ...
# 18036  198507  198202
# 18037  197206  198008
# 18038  196401  195712
# 18039  197905  196405
# 18040  197307  197202
#
# [18041 rows x 21 columns]
